# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('daily_close.csv').dropna(how='any')
df = df.set_index('Date')
df.index = pd.to_datetime(df.index, utc=True)
df = df[df['Close'] != 0]

# %%
data = pd.read_csv('../data/tech.csv').dropna(how = 'any', axis = 0)
data = data.sort_values(by='Market Cap', ascending=False).reset_index()
symbols = data['Symbol']
len(symbols)
# Out:
# 519

# %%
annual_returns_list = []
no_data_stocks = []
for i, ticker in enumerate(symbols):
    try:
        print(f'calculating annual returns of {ticker} stock {i}/{len(symbols)}')
        annual_returns_ticker = df[df['ticker'] == ticker]
        annual_returns = annual_returns_ticker['Close'].resample('A')
        annual_returns_df = pd.DataFrame((annual_returns.last()-annual_returns.first())/annual_returns.last())
        annual_returns_df['ticker'] = ticker
        annual_returns_list.append(annual_returns_df)
    except:
        print(f'ticker {ticker} not found')
        no_data_stocks.append(ticker)
# Out:
# calculating annual returns of AAPL
# calculating annual returns of MSFT
# calculating annual returns of GOOG
# calculating annual returns of GOOGL
# calculating annual returns of NVDA
# calculating annual returns of META
# calculating annual returns of TSM
# calculating annual returns of AVGO
# calculating annual returns of ORCL
# calculating annual returns of ASML
# calculating annual returns of ADBE
# calculating annual returns of CRM
# calculating annual returns of INTU
# calculating annual returns of QCOM
# calculating annual returns of NOW
# calculating annual returns of AMAT
# calculating annual returns of VRTX
# calculating annual returns of LRCX
# calculating annual returns of KLAC
# calculating annual returns of SNPS
# calculating annual returns of SNOW
# calculating annual returns of CRWD
# calculating annual returns of TEAM
# calculating annual returns of DELL
# calculating annual returns of NXPI
# calculating annual returns of MRVL
# calculating annual returns of MCHP
# calculating annual returns of FTNT
# calculating annual returns of SQ
# calculating annual returns of BIDU
# calculating annual returns of DDOG
# calculating annual returns of CTSH
# calculating annual returns of OTIS
# calculating annual returns of PLTR
# calculating annual returns of VRSK
# calculating annual returns of TTD
# calculating annual returns of ZS
# calculating annual returns of GFS
# calculating annual returns of VEEV
# calculating annual returns of MPWR
# calculating annual returns of TTWO
# calculating annual returns of HUBS
# calculating annual returns of SNAP
# calculating annual returns of RBLX
# calculating annual returns of MDB
# calculating annual returns of NET
# calculating annual returns of SPLK
# calculating annual returns of PINS
# calculating annual returns of HPE
# calculating annual returns of ZM
# calculating annual returns of VRSN
# calculating annual returns of NOK
# calculating annual returns of ASX
# calculating annual returns of CHKP
# calculating annual returns of FSLR
# calculating annual returns of NTAP
# calculating annual returns of VRT
# calculating annual returns of FDS
# calculating annual returns of HUBB
# calculating annual returns of STX
# calculating annual returns of EPAM
# calculating annual returns of IOT
# calculating annual returns of JBL
# calculating annual returns of ENPH
# calculating annual returns of SMCI
# calculating annual returns of DT
# calculating annual returns of LOGI
# calculating annual returns of SSNC
# calculating annual returns of GDDY
# calculating annual returns of U
# calculating annual returns of BSY
# calculating annual returns of OKTA
# calculating annual returns of ZBRA
# calculating annual returns of PATH
# calculating annual returns of APP
# calculating annual returns of TWLO
# calculating annual returns of MANH
# calculating annual returns of JKHY
# calculating annual returns of PAYC
# calculating annual returns of PSTG
# calculating annual returns of DOCU
# calculating annual returns of NTNX
# calculating annual returns of HOOD
# calculating annual returns of ESTC
# calculating annual returns of FLEX
# calculating annual returns of CDAY
# calculating annual returns of DLB
# calculating annual returns of DBX
# calculating annual returns of SNX
# calculating annual returns of JNPR
# calculating annual returns of MSTR
# calculating annual returns of GLOB
# calculating annual returns of TOST
# calculating annual returns of PCOR
# calculating annual returns of GTLB
# calculating annual returns of PCTY
# calculating annual returns of DUOL
# calculating annual returns of CYBR
# calculating annual returns of GWRE
# calculating annual returns of MNDY
# calculating annual returns of BILL
# calculating annual returns of INFA
# calculating annual returns of AMKR
# calculating annual returns of YMM
# calculating annual returns of S
# calculating annual returns of QLYS
# calculating annual returns of RMBS
# calculating annual returns of CFLT
# calculating annual returns of BZ
# calculating annual returns of WIX
# calculating annual returns of SPSC
# calculating annual returns of ZI
# calculating annual returns of PSN
# calculating annual returns of ALTR
# calculating annual returns of FRSH
# calculating annual returns of GLBE
# calculating annual returns of SMAR
# calculating annual returns of CLVT
# calculating annual returns of APPF
# calculating annual returns of MTSI
# calculating annual returns of DV
# calculating annual returns of NSIT
# calculating annual returns of FIVN
# calculating annual returns of DOCS
# calculating annual returns of ALGM
# calculating annual returns of TENB
# calculating annual returns of WK
# calculating annual returns of EXLS
# calculating annual returns of AUR
# calculating annual returns of BRZE
# calculating annual returns of CWAN
# calculating annual returns of IPGP
# calculating annual returns of SEDG
# calculating annual returns of STNE
# calculating annual returns of VRNS
# calculating annual returns of PWSC
# calculating annual returns of BILI
# calculating annual returns of BLKB
# calculating annual returns of KD
# calculating annual returns of POWI
# calculating annual returns of ASGN
# calculating annual returns of HCP
# calculating annual returns of DAVA
# calculating annual returns of CRUS
# calculating annual returns of SQSP
# calculating annual returns of SYNA
# calculating annual returns of VERX
# calculating annual returns of ESMT
# calculating annual returns of PEGA
# calculating annual returns of SLAB
# calculating annual returns of ACLS
# calculating annual returns of ASAN
# calculating annual returns of ENS
# calculating annual returns of NVMI
# calculating annual returns of AEIS
# calculating annual returns of NCNO
# calculating annual returns of BOX
# calculating annual returns of PYCR
# calculating annual returns of RELY
# calculating annual returns of BL
# calculating annual returns of LPL
# calculating annual returns of MQ
# calculating annual returns of VSAT
# calculating annual returns of CLS
# calculating annual returns of AYX
# calculating annual returns of ATHM
# calculating annual returns of AI
# calculating annual returns of TSEM
# calculating annual returns of CVLT
# calculating annual returns of FROG
# calculating annual returns of CXM
# calculating annual returns of RPD
# calculating annual returns of YOU
# calculating annual returns of SPT
# calculating annual returns of CAMT
# calculating annual returns of ALRM
# calculating annual returns of DOCN
# calculating annual returns of FORM
# calculating annual returns of PLTK
# calculating annual returns of RNG
# calculating annual returns of COUR
# calculating annual returns of GBTG
# calculating annual returns of APPN
# calculating annual returns of MBLY
# calculating annual returns of SANM
# calculating annual returns of CRDO
# calculating annual returns of HAYW
# calculating annual returns of NXT
# calculating annual returns of CERT
# calculating annual returns of ENV
# calculating annual returns of PRVA
# calculating annual returns of EVTC
# calculating annual returns of FLYW
# calculating annual returns of CARG
# calculating annual returns of INTA
# calculating annual returns of SITM
# calculating annual returns of WB
# calculating annual returns of SHLS
# calculating annual returns of PAGS
# calculating annual returns of NABL
# calculating annual returns of ARRY
# calculating annual returns of QTWO
# calculating annual returns of AVDX
# calculating annual returns of YY
# calculating annual returns of RAMP
# calculating annual returns of GDRX
# calculating annual returns of MIR
# calculating annual returns of PRGS
# calculating annual returns of IAS
# calculating annual returns of SRAD
# calculating annual returns of PI
# calculating annual returns of AMBA
# calculating annual returns of JAMF
# calculating annual returns of OSIS
# calculating annual returns of ALKT
# calculating annual returns of FSLY
# calculating annual returns of PRFT
# calculating annual returns of PLUS
# calculating annual returns of PAY
# calculating annual returns of SIMO
# calculating annual returns of MRCY
# calculating annual returns of PD
# calculating annual returns of BMBL
# calculating annual returns of LZ
# calculating annual returns of SWI
# calculating annual returns of EVCM
# calculating annual returns of UPWK
# calculating annual returns of DQ
# calculating annual returns of PLAB
# calculating annual returns of SEMR
# calculating annual returns of MLNK
# calculating annual returns of MXL
# calculating annual returns of ZETA
# calculating annual returns of RUM
# calculating annual returns of JKS
# calculating annual returns of COMP
# calculating annual returns of SSTK
# calculating annual returns of VECO
# calculating annual returns of SABR
# calculating annual returns of VRNT
# calculating annual returns of PRO
# calculating annual returns of CSIQ
# calculating annual returns of GDS
# calculating annual returns of OMCL
# calculating annual returns of CSGS
# calculating annual returns of XMTR
# calculating annual returns of TTMI
# calculating annual returns of NTCT
# calculating annual returns of SPNS
# calculating annual returns of GRND
# calculating annual returns of AVPT
# calculating annual returns of TWKS
# calculating annual returns of UCTT
# calculating annual returns of CRSR
# calculating annual returns of HLIT
# calculating annual returns of PERI
# calculating annual returns of ADEA
# calculating annual returns of ETWO
# calculating annual returns of STER
# calculating annual returns of MOMO
# calculating annual returns of TUYA
# calculating annual returns of LAZR
# calculating annual returns of ENFN
# calculating annual returns of ZUO
# calculating annual returns of PDFS
# calculating annual returns of OPRA
# calculating annual returns of TASK
# calculating annual returns of NRDS
# calculating annual returns of HIMX
# calculating annual returns of ACMR
# calculating annual returns of DH
# calculating annual returns of ERII
# calculating annual returns of BASE
# calculating annual returns of MODN
# calculating annual returns of GDYN
# calculating annual returns of ICHR
# calculating annual returns of YALA
# calculating annual returns of SSYS
# calculating annual returns of SGH
# calculating annual returns of WKME
# calculating annual returns of EVBG
# calculating annual returns of DGII
# calculating annual returns of KC
# calculating annual returns of HUYA
# calculating annual returns of DADA
# calculating annual returns of EB
# calculating annual returns of WEAV
# calculating annual returns of PUBM
# calculating annual returns of AOSL
# calculating annual returns of DWACU
# calculating annual returns of KARO
# calculating annual returns of MTTR
# calculating annual returns of SPWR
# calculating annual returns of TRMR
# calculating annual returns of EVLV
# calculating annual returns of YEXT
# calculating annual returns of ML
# calculating annual returns of BIGC
# calculating annual returns of DWAC
# calculating annual returns of AAOI
# calculating annual returns of BLND
# calculating annual returns of LASR
# calculating annual returns of COMM
# calculating annual returns of SCWX
# calculating annual returns of STEM
# calculating annual returns of VTEX
# calculating annual returns of ITRN
# calculating annual returns of FRGE
# calculating annual returns of NRDY
# calculating annual returns of HCAT
# calculating annual returns of MGIC
# calculating annual returns of MVIS
# calculating annual returns of AUROW
# calculating annual returns of XPER
# calculating annual returns of IREN
# calculating annual returns of LAW
# calculating annual returns of DSP
# calculating annual returns of SKYT
# calculating annual returns of CAN
# calculating annual returns of VNET
# calculating annual returns of RXT
# calculating annual returns of EVER
# calculating annual returns of DDI
# calculating annual returns of RUMBW
# calculating annual returns of AMWL
# calculating annual returns of CERS
# calculating annual returns of SHCR
# calculating annual returns of MTLS
# calculating annual returns of DOMO
# calculating annual returns of BAND
# calculating annual returns of ICG
# calculating annual returns of MYPS
# calculating annual returns of IBEX
# calculating annual returns of SSTI
# calculating annual returns of BBAI
# calculating annual returns of ONTF
# calculating annual returns of TRUE
# calculating annual returns of MX
# calculating annual returns of LPSN
# calculating annual returns of LIFW
# calculating annual returns of CDLX
# calculating annual returns of OUST
# calculating annual returns of DOYU
# calculating annual returns of PRCH
# calculating annual returns of BLZE
# calculating annual returns of TLS
# calculating annual returns of API
# calculating annual returns of OOMA
# calculating annual returns of PERF
# calculating annual returns of PRTH
# calculating annual returns of INSE
# calculating annual returns of EGAN
# calculating annual returns of KLTR
# calculating annual returns of KOPN
# calculating annual returns of INOD
# calculating annual returns of IMMR
# calculating annual returns of DM
# calculating annual returns of AVPTW
# calculating annual returns of AIP
# calculating annual returns of DWACW
# calculating annual returns of QUIK
# calculating annual returns of BKSY
# calculating annual returns of MIXT
# calculating annual returns of MRAM
# calculating annual returns of DRCT
# calculating annual returns of EXFY
# calculating annual returns of RELL
# calculating annual returns of MTC
# calculating annual returns of TRVG
# calculating annual returns of ATOM
# calculating annual returns of CMBM
# calculating annual returns of SOL
# calculating annual returns of CPSI
# calculating annual returns of ISSC
# calculating annual returns of AIXI
# calculating annual returns of MKFG
# calculating annual returns of SQNS
# calculating annual returns of NOTE
# calculating annual returns of UPLD
# calculating annual returns of SY
# calculating annual returns of ALOT
# calculating annual returns of MAPS
# calculating annual returns of SKLZ
# calculating annual returns of RDCM
# calculating annual returns of SKIL
# calculating annual returns of SJ
# calculating annual returns of OCFT
# calculating annual returns of IVAC
# calculating annual returns of EVLVW
# calculating annual returns of AXTI
# calculating annual returns of CCRD
# calculating annual returns of BCOV
# calculating annual returns of KVHI
# calculating annual returns of XNET
# calculating annual returns of SOUNW
# calculating annual returns of CSPI
# calculating annual returns of TWOU
# calculating annual returns of ZEPP
# calculating annual returns of ELTK
# calculating annual returns of FTCI
# calculating annual returns of WGS
# calculating annual returns of PXLW
# calculating annual returns of GAN
# calculating annual returns of TACT
# calculating annual returns of PET
# calculating annual returns of WIMI
# calculating annual returns of EBON
# calculating annual returns of CMCM
# calculating annual returns of VERI
# calculating annual returns of GSIT
# calculating annual returns of BEAT
# calculating annual returns of SMSI
# calculating annual returns of SNCR
# calculating annual returns of ESP
# calculating annual returns of CASA
# calculating annual returns of IPWR
# calculating annual returns of AGMH
# calculating annual returns of LPTH
# calculating annual returns of ARBB
# calculating annual returns of KTCC
# calculating annual returns of CMAX
# calculating annual returns of OSS
# calculating annual returns of SNAL
# calculating annual returns of HRYU
# calculating annual returns of ICLK
# calculating annual returns of EMKR
# calculating annual returns of AIRG
# calculating annual returns of AKLI
# calculating annual returns of GSD
# calculating annual returns of XPON
# calculating annual returns of MLGO
# calculating annual returns of AWRE
# calculating annual returns of IDN
# calculating annual returns of SNCE
# calculating annual returns of MVLA
# calculating annual returns of LGL
# calculating annual returns of DFLI
# calculating annual returns of CHR
# calculating annual returns of HLTH
# calculating annual returns of ALAR
# calculating annual returns of PRST
# calculating annual returns of CCLD
# calculating annual returns of CLPS
# calculating annual returns of BMR
# calculating annual returns of TAIT
# calculating annual returns of ZENV
# calculating annual returns of TRT
# calculating annual returns of IPDN
# calculating annual returns of XELA
# calculating annual returns of JG
# calculating annual returns of VRAR
# calculating annual returns of SGMA
# calculating annual returns of CXAI
# calculating annual returns of BFRG
# calculating annual returns of HOLO
# calculating annual returns of SAI
# calculating annual returns of SHCRW
# calculating annual returns of LIFWZ
# calculating annual returns of LIZI
# calculating annual returns of HTCR
# calculating annual returns of MYPSW
# calculating annual returns of HCTI
# calculating annual returns of TRNR
# calculating annual returns of HKIT
# calculating annual returns of OST
# calculating annual returns of BEATW
# calculating annual returns of PHUN
# calculating annual returns of LFLY
# calculating annual returns of ISUN
# calculating annual returns of CAMP
# calculating annual returns of PT
# calculating annual returns of MSGM
# calculating annual returns of SOPA
# calculating annual returns of BLIN
# calculating annual returns of WATT
# calculating annual returns of ASST
# calculating annual returns of MAPSW
# calculating annual returns of EZFL
# calculating annual returns of PBTS
# calculating annual returns of INPX
# calculating annual returns of BFRGW
# calculating annual returns of BYU
# calculating annual returns of DATS
# calculating annual returns of PETWW
# calculating annual returns of AMST
# calculating annual returns of BURU
# calculating annual returns of LEDS
# calculating annual returns of AULT
# calculating annual returns of CYN
# calculating annual returns of MGRX
# calculating annual returns of AUUD
# calculating annual returns of IFBD
# calculating annual returns of KERN
# calculating annual returns of UUU
# calculating annual returns of NFTG
# calculating annual returns of LYT
# calculating annual returns of WTO
# calculating annual returns of ONFO
# calculating annual returns of TGL
# calculating annual returns of WISA
# calculating annual returns of HOLOW
# calculating annual returns of ACON
# calculating annual returns of CXAIW
# calculating annual returns of PRSTW
# calculating annual returns of DFLIW
# calculating annual returns of MVLAW
# calculating annual returns of CMAXW
# calculating annual returns of DATSW
# calculating annual returns of ACONW
# calculating annual returns of WGSWW
# calculating annual returns of KERNW
# calculating annual returns of GSMGW
# calculating annual returns of LFLYW
# calculating annual returns of GSDWW
# calculating annual returns of AOGO
# calculating annual returns of WAVSW
# calculating annual returns of TYGO
# calculating annual returns of AOGOW
# calculating annual returns of WAVS

# %%
annual_returns = pd.concat(annual_returns_list)
annual_returns
# Out:
#                               Close ticker
# Date
# 1994-12-31 00:00:00+00:00  0.149797   AAPL
# 1995-12-31 00:00:00+00:00 -0.190334   AAPL
# 1996-12-31 00:00:00+00:00 -0.538918   AAPL
# 1997-12-31 00:00:00+00:00 -0.599993   AAPL
# 1998-12-31 00:00:00+00:00  0.603054   AAPL
# ...                             ...    ...
# 2024-12-31 00:00:00+00:00 -0.158824   TYGO
# 2024-12-31 00:00:00+00:00  0.000000  AOGOW
# 2022-12-31 00:00:00+00:00  0.141991   WAVS
# 2023-12-31 00:00:00+00:00  0.034070   WAVS
# 2024-12-31 00:00:00+00:00 -0.010781   WAVS
#
# [5976 rows x 2 columns]

# %%
df = df[df['ticker'] == 'AAPL']
annual_returns = df['Close'].resample('A')
plt.plot((annual_returns.last()-annual_returns.first())/annual_returns.last(), '.')

# %%
annual_returns.asfreq()
# Out:
# Date
# 1994-12-31 00:00:00-05:00           NaN
# 1995-12-31 00:00:00-05:00           NaN
# 1996-12-31 00:00:00-05:00      6.403062
# 1997-12-31 00:00:00-05:00     10.016294
# 1998-12-31 00:00:00-05:00     21.495306
# 1999-12-31 00:00:00-05:00     36.190376
# 2000-12-31 00:00:00-05:00           NaN
# 2001-12-31 00:00:00-05:00     20.536299
# 2002-12-31 00:00:00-05:00     16.026058
# 2003-12-31 00:00:00-05:00     17.118469
# 2004-12-31 00:00:00-05:00     18.681070
# 2005-12-31 00:00:00-05:00           NaN
# 2006-12-31 00:00:00-05:00           NaN
# 2007-12-31 00:00:00-05:00     25.905088
# 2008-12-31 00:00:00-05:00     14.406952
# 2009-12-31 00:00:00-05:00     23.118437
# 2010-12-31 00:00:00-05:00     21.610043
# 2011-12-31 00:00:00-05:00           NaN
# 2012-12-31 00:00:00-05:00     21.830753
# 2013-12-31 00:00:00-05:00     31.501337
# 2014-12-31 00:00:00-05:00     40.184559
# 2015-12-31 00:00:00-05:00     49.303169
# 2016-12-31 00:00:00-05:00           NaN
# 2017-12-31 00:00:00-05:00           NaN
# 2018-12-31 00:00:00-05:00     96.450592
# 2019-12-31 00:00:00-05:00    151.965714
# 2020-12-31 00:00:00-05:00    216.602890
# 2021-12-31 00:00:00-05:00    330.269470
# 2022-12-31 00:00:00-05:00           NaN
# 2023-12-31 00:00:00-05:00           NaN
# 2024-12-31 00:00:00-05:00           NaN
# Freq: A-DEC, Name: Close, dtype: float64
